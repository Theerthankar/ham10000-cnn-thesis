# %% [markdown]
# # E4 - ResNet-50, weighted cross-entropy, 224px
#
# | | |
# |---|---|
# | Architecture | `resnet50` |
# | Imbalance strategy | `weighted_ce` |
# | Input resolution | 224x224 |
# | Group | confirmatory 2x3 factorial |
# | Optimiser | Adam, lr 1e-3, betas (0.9, 0.999) |
# | Batch size | 32 |
# | Schedule | max 50 epochs, early stopping on val loss, patience 10 |
# | Seed | 42 |
#
# The most fragile configuration in the set: ResNet-50's optimisation
# sensitivity meets weighted CE's aggressive rare-class weights.
#
# In the earlier round this run showed an outright mid-training collapse, with validation
# loss spiking and accuracy briefly falling to roughly a quarter before partially
# recovering. If that happens again, let it run. It is evidence, and lowering the
# learning rate for this one run would break the controlled comparison.
#
# Training is checkpointed after every epoch. If the pod drops, re-run the training cell
# and it picks up from the last completed epoch rather than starting over.

# %%
import json, sys, time
from pathlib import Path

# Works whether the kernel starts in notebooks/ or at the repo root.
ROOT = Path.cwd()
while not (ROOT / "src" / "ham10000").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

# /workspace is a MooseFS network volume and per-file reads over FUSE were the
# bottleneck, not the GPU: 45 img/s there against 241 img/s from RAM. Notebook 01
# stages a copy into /dev/shm. Fall back to the on-disk copy if it is missing,
# since tmpfs does not survive a pod restart.
FAST = Path("/dev/shm/ham_data")
DATA = FAST if (FAST / "HAM10000_metadata.csv").exists() else ROOT / "data"
RUNS = ROOT / "runs"
print("repo:   ", ROOT)
print("data:   ", DATA, "(RAM)" if str(DATA).startswith("/dev/shm") else "(disk, slower)")
# Out:
# repo:    /workspace/ham10000-cnn-comparison
# data:    /dev/shm/ham_data (RAM)

# %%
from ham10000.constants import EXPERIMENTS, experiment_label
from ham10000.train import TrainConfig, train_experiment

EXP = "E4"
print(experiment_label(EXP))
print(EXPERIMENTS[EXP])
# Out:
# E4 ResNet-50 @224 / Weighted CE
# {'architecture': 'resnet50', 'strategy': 'weighted_ce', 'image_size': 224}

# %% [markdown]
# ## Preflight
#
# Confirms the GPU, the data and the shared split before anything expensive starts.

# %%
import torch
from ham10000.split import load_or_create_split, split_hash

assert torch.cuda.is_available(), "No GPU. Stop here."
print("gpu :", torch.cuda.get_device_name(0))

assert (DATA / "HAM10000_metadata.csv").exists(), "Run notebook 01 first."
df, lesion_splits = load_or_create_split(DATA / "HAM10000_metadata.csv",
                                         RUNS / "splits" / "seed42_lesion_stratified.json")
print("split hash :", split_hash(lesion_splits))
print(df.split.value_counts().to_dict())
# Out:
# gpu : NVIDIA RTX A4500
# split hash : f35ac1de18678182
# {'train': 8012, 'test': 1024, 'val': 979}

# %% [markdown]
# ## Train
#
# Expect this to take a while. Roughly 30 to 60 minutes on an A40, depending on how early the run stops.
#
# The cell is safe to re-run: if `test_metrics.json` already exists it returns the cached
# result instead of retraining. Pass `force_rerun=True` if you genuinely want it redone.

# %%
config = TrainConfig(
    experiment_id=EXP,
    data_root=str(DATA),
    output_dir=str(RUNS / EXP),
    seed=42,
    batch_size=32,
    lr=1e-3,
    max_epochs=50,
    patience=10,
    num_workers=16,
)

start = time.time()
result = train_experiment(config)
print(f"\nwall clock: {(time.time() - start) / 60:.1f} min")
# Out:
# Epoch 1/50 | train loss 2.0156 acc 0.2547 | val loss 1.5870 macro-F1 0.2078
# Epoch 2/50 | train loss 1.7237 acc 0.4295 | val loss 2.0201 macro-F1 0.2146
# Epoch 3/50 | train loss 1.6457 acc 0.4486 | val loss 1.3902 macro-F1 0.2278
# Epoch 4/50 | train loss 1.5187 acc 0.4758 | val loss 1.1928 macro-F1 0.3753
# Epoch 5/50 | train loss 1.4931 acc 0.4914 | val loss 1.2046 macro-F1 0.3141
# Epoch 6/50 | train loss 1.4730 acc 0.5084 | val loss 1.0838 macro-F1 0.2741
# Epoch 7/50 | train loss 1.3910 acc 0.5327 | val loss 1.8911 macro-F1 0.2411
# Epoch 8/50 | train loss 1.3929 acc 0.5311 | val loss 1.3363 macro-F1 0.3180
# Epoch 9/50 | train loss 1.3043 acc 0.5357 | val loss 1.0057 macro-F1 0.3803
# Epoch 10/50 | train loss 1.3291 acc 0.5527 | val loss 1.2145 macro-F1 0.4234
# Epoch 11/50 | train loss 1.2663 acc 0.5655 | val loss 1.0889 macro-F1 0.3938
# Epoch 12/50 | train loss 1.2532 acc 0.5688 | val loss 1.0083 macro-F1 0.4154
# Epoch 13/50 | train loss 1.2228 acc 0.5623 | val loss 1.1626 macro-F1 0.3799
# Epoch 14/50 | train loss 1.2269 acc 0.5675 | val loss 1.1208 macro-F1 0.3579
# Epoch 15/50 | train loss 1.2556 acc 0.5657 | val loss 1.2410 macro-F1 0.3634
# Epoch 16/50 | train loss 1.2787 acc 0.5557 | val loss 1.1568 macro-F1 0.4152
# Epoch 17/50 | train loss 1.2043 acc 0.5780 | val loss 0.9863 macro-F1 0.4351
# Epoch 18/50 | train loss 1.1140 acc 0.5932 | val loss 1.0442 macro-F1 0.3597
# Epoch 19/50 | train loss 1.1462 acc 0.5919 | val loss 1.0652 macro-F1 0.4237
# Epoch 20/50 | train loss 1.1220 acc 0.5846 | val loss 1.0399 macro-F1 0.3931
# Epoch 21/50 | train loss 1.1067 acc 0.6011 | val loss 1.0745 macro-F1 0.4031
# Epoch 22/50 | train loss 1.0975 acc 0.5940 | val loss 1.0070 macro-F1 0.3993
# Epoch 23/50 | train loss 1.0801 acc 0.6031 | val loss 1.0864 macro-F1 0.3836
# Epoch 24/50 | train loss 1.0447 acc 0.6037 | val loss 1.0871 macro-F1 0.4016
# Epoch 25/50 | train loss 1.0392 acc 0.6132 | val loss 0.9647 macro-F1 0.4303
# Epoch 26/50 | train loss 1.0415 acc 0.6113 | val loss 1.0743 macro-F1 0.4073
# Epoch 27/50 | train loss 1.0343 acc 0.6145 | val loss 1.1566 macro-F1 0.3847
# Epoch 28/50 | train loss 1.0267 acc 0.6135 | val loss 1.0110 macro-F1 0.4417
# Epoch 29/50 | train loss 1.0080 acc 0.6174 | val loss 0.8991 macro-F1 0.4688
# Epoch 30/50 | train loss 1.0055 acc 0.6071 | val loss 1.2519 macro-F1 0.3535
# Epoch 31/50 | train loss 0.9476 acc 0.6279 | val loss 0.8936 macro-F1 0.4430
# Epoch 32/50 | train loss 0.9691 acc 0.6389 | val loss 1.1651 macro-F1 0.3853
# Epoch 33/50 | train loss 0.9481 acc 0.6479 | val loss 0.8605 macro-F1 0.4446
# Epoch 34/50 | train loss 0.9158 acc 0.6458 | val loss 2.0671 macro-F1 0.2848
# Epoch 35/50 | train loss 0.9112 acc 0.6318 | val loss 0.8268 macro-F1 0.4966
# Epoch 36/50 | train loss 0.9153 acc 0.6412 | val loss 0.8200 macro-F1 0.5106
# Epoch 37/50 | train loss 0.9102 acc 0.6520 | val loss 0.9726 macro-F1 0.3993
# Epoch 38/50 | train loss 0.8712 acc 0.6556 | val loss 0.9670 macro-F1 0.4927
# Epoch 39/50 | train loss 0.8848 acc 0.6497 | val loss 0.9396 macro-F1 0.4903
# Epoch 40/50 | train loss 0.8641 acc 0.6539 | val loss 0.7852 macro-F1 0.5088
# Epoch 41/50 | train loss 0.8500 acc 0.6575 | val loss 0.8756 macro-F1 0.4559
# Epoch 42/50 | train loss 0.8257 acc 0.6643 | val loss 0.9900 macro-F1 0.4658
# Epoch 43/50 | train loss 0.8305 acc 0.6589 | val loss 0.8962 macro-F1 0.4931
# Epoch 44/50 | train loss 0.8500 acc 0.6566 | val loss 0.9103 macro-F1 0.5325
# Epoch 45/50 | train loss 0.8428 acc 0.6538 | val loss 0.9393 macro-F1 0.4581
# Epoch 46/50 | train loss 0.8222 acc 0.6675 | val loss 0.7770 macro-F1 0.5112
# Epoch 47/50 | train loss 0.8045 acc 0.6789 | val loss 1.0056 macro-F1 0.5396
# Epoch 48/50 | train loss 0.7899 acc 0.6777 | val loss 0.9328 macro-F1 0.4556
# Epoch 49/50 | train loss 0.8031 acc 0.6710 | val loss 0.7915 macro-F1 0.5705
# Epoch 50/50 | train loss 0.7746 acc 0.6766 | val loss 0.8565 macro-F1 0.5238
#
# === E4 test metrics (best checkpoint) ===
# Accuracy          0.6992
# Balanced accuracy 0.5573
# Macro F1          0.4834
# Per-class F1      {"akiec": 0.3529, "bcc": 0.275, "bkl": 0.5079, "df": 0.3492, "mel": 0.45, "nv": 0.856, "vasc": 0.5926}
#
# wall clock: 25.8 min

# %% [markdown]
# ## Results

# %%
import pandas as pd
from ham10000.constants import CLASS_NAMES

m = result["test_metrics"]
report = m["classification_report"]

print(f"accuracy          {m['accuracy']:.4f}")
print(f"balanced accuracy {m['balanced_accuracy']:.4f}")
print(f"macro F1          {m['macro_f1']:.4f}")
print(f"macro AUC (OvR)   {m['macro_auc_ovr']:.4f}\n")

table = pd.DataFrame([{
    "class": c,
    "precision": report[str(i)]["precision"],
    "recall": report[str(i)]["recall"],
    "f1": report[str(i)]["f1-score"],
    "support": int(report[str(i)]["support"]),
} for i, c in enumerate(CLASS_NAMES)]).set_index("class").round(4)
print(table)

rq2 = (report[str(CLASS_NAMES.index("mel"))]["recall"]
       + report[str(CLASS_NAMES.index("bcc"))]["recall"]) / 2
print(f"\nRQ2 criterion, mean(recall MEL, recall BCC) = {rq2:.4f}")
# Out:
# accuracy          0.6992
# balanced accuracy 0.5573
# macro F1          0.4834
# macro AUC (OvR)   0.9294
#
#        precision  recall      f1  support
# class
# akiec     0.3429  0.3636  0.3529       33
# bcc       0.4074  0.2075  0.2750       53
# bkl       0.4354  0.6095  0.5079      105
# df        0.2200  0.8462  0.3492       13
# mel       0.3818  0.5478  0.4500      115
# nv        0.9303  0.7928  0.8560      690
# vasc      0.6667  0.5333  0.5926       15
#
# RQ2 criterion, mean(recall MEL, recall BCC) = 0.3777

# %% [markdown]
# ### Training curve
#
# Val loss is what early stopping watches. Val macro F1 is what actually matters, and the
# two do not always move together.

# %%
import matplotlib.pyplot as plt

h = pd.read_csv(RUNS / EXP / "history.csv")
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(h.epoch, h.train_loss, label="train")
axes[0].plot(h.epoch, h.val_loss, label="val")
best = h.loc[h.val_loss.idxmin()]
axes[0].axvline(best.epoch, ls="--", c="grey", lw=1)
axes[0].annotate(f"best epoch {int(best.epoch)}", (best.epoch, best.val_loss),
                 textcoords="offset points", xytext=(8, 10), fontsize=8)
axes[0].set_xlabel("epoch"); axes[0].set_ylabel("loss"); axes[0].legend()
axes[0].set_title(f"{EXP} loss")

axes[1].plot(h.epoch, h.val_macro_f1, color="#D54407", label="val macro F1")
axes[1].plot(h.epoch, h.val_balanced_accuracy, color="#2E7D32", label="val balanced acc")
axes[1].set_xlabel("epoch"); axes[1].legend(); axes[1].set_title(f"{EXP} validation metrics")
plt.show()

print(f"stopped after {len(h)} epochs, best val loss {h.val_loss.min():.4f} at epoch {int(best.epoch)}")
# Out:
# stopped after 50 epochs, best val loss 0.7770 at epoch 46

# %% [markdown]
# ### Confusion matrix

# %%
import numpy as np

cm = np.array(m["confusion_matrix"], dtype=float)
norm = cm / np.maximum(cm.sum(axis=1, keepdims=True), 1)

fig, ax = plt.subplots(figsize=(6, 5))
ax.imshow(norm, cmap="Oranges", vmin=0, vmax=1)
for i in range(7):
    for j in range(7):
        if cm[i, j]:
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", fontsize=8,
                    color="white" if norm[i, j] > 0.55 else "black")
ax.set_xticks(range(7), [c.upper() for c in CLASS_NAMES], rotation=45)
ax.set_yticks(range(7), [c.upper() for c in CLASS_NAMES])
ax.set_xlabel("predicted"); ax.set_ylabel("true")
ax.set_title(f"{EXP} confusion matrix (counts, shaded by row-normalised recall)")
ax.grid(False)
plt.show()

mel, nv = CLASS_NAMES.index("mel"), CLASS_NAMES.index("nv")
print(f"melanomas called NV: {int(cm[mel, nv])} of {int(cm[mel].sum())}")
print("This is the clinically costly error: a cancer sent home as a benign mole.")
# Out:
# melanomas called NV: 23 of 115
# This is the clinically costly error: a cancer sent home as a benign mole.

# %% [markdown]
# ### Files written
#
# These five are what the analysis notebooks read. Nothing later re-derives them.

# %%
for f in sorted((RUNS / EXP).iterdir()):
    print(f"{f.name:<24} {f.stat().st_size/1e6:>8.2f} MB")
# Out:
# checkpoint_best.pt         282.73 MB
# checkpoint_last.pt         282.73 MB
# config.json                  0.00 MB
# history.csv                  0.00 MB
# test_metrics.json            0.00 MB
# test_predictions.csv         0.02 MB
