# %% [markdown]
# # E5 - MobileNetV2, random oversampling, 224px
#
# | | |
# |---|---|
# | Architecture | `mobilenet_v2` |
# | Imbalance strategy | `oversampling` |
# | Input resolution | 224x224 |
# | Group | confirmatory 2x3 factorial |
# | Optimiser | Adam, lr 1e-3, betas (0.9, 0.999) |
# | Batch size | 32 |
# | Schedule | max 50 epochs, early stopping on val loss, patience 10 |
# | Seed | 42 |
#
# Oversampling instead of loss weighting. The WeightedRandomSampler draws
# with replacement at probability proportional to 1/n_c, so rare classes come up far
# more often per epoch while the loss itself stays unweighted.
#
# Buda et al. report oversampling as the stronger of the two remediations on CNNs and
# find it does not cause the overfitting it can in classical models. This run is where
# that claim gets tested on HAM10000.
#
# Training is checkpointed after every epoch. If the pod drops, re-run the training cell
# and it picks up from the last completed epoch rather than starting over.

# %%
import json, sys, time
from pathlib import Path

# Works whether the kernel starts in notebooks/ or at the repo root.
ROOT = Path.cwd()
while not (ROOT / "src" / "ham10000").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

# /workspace is a MooseFS network volume and per-file reads over FUSE were the
# bottleneck, not the GPU: 45 img/s there against 241 img/s from RAM. Notebook 01
# stages a copy into /dev/shm. Fall back to the on-disk copy if it is missing,
# since tmpfs does not survive a pod restart.
FAST = Path("/dev/shm/ham_data")
DATA = FAST if (FAST / "HAM10000_metadata.csv").exists() else ROOT / "data"
RUNS = ROOT / "runs"
print("repo:   ", ROOT)
print("data:   ", DATA, "(RAM)" if str(DATA).startswith("/dev/shm") else "(disk, slower)")
# Out:
# repo:    /workspace/ham10000-cnn-comparison
# data:    /dev/shm/ham_data (RAM)

# %%
from ham10000.constants import EXPERIMENTS, experiment_label
from ham10000.train import TrainConfig, train_experiment

EXP = "E5"
print(experiment_label(EXP))
print(EXPERIMENTS[EXP])
# Out:
# E5 MobileNetV2 @224 / Random oversampling
# {'architecture': 'mobilenet_v2', 'strategy': 'oversampling', 'image_size': 224}

# %% [markdown]
# ## Preflight
#
# Confirms the GPU, the data and the shared split before anything expensive starts.

# %%
import torch
from ham10000.split import load_or_create_split, split_hash

assert torch.cuda.is_available(), "No GPU. Stop here."
print("gpu :", torch.cuda.get_device_name(0))

assert (DATA / "HAM10000_metadata.csv").exists(), "Run notebook 01 first."
df, lesion_splits = load_or_create_split(DATA / "HAM10000_metadata.csv",
                                         RUNS / "splits" / "seed42_lesion_stratified.json")
print("split hash :", split_hash(lesion_splits))
print(df.split.value_counts().to_dict())
# Out:
# gpu : NVIDIA RTX A4500
# split hash : f35ac1de18678182
# {'train': 8012, 'test': 1024, 'val': 979}

# %% [markdown]
# ## Train
#
# Expect this to take a while. Roughly 30 to 60 minutes on an A40, depending on how early the run stops.
#
# The cell is safe to re-run: if `test_metrics.json` already exists it returns the cached
# result instead of retraining. Pass `force_rerun=True` if you genuinely want it redone.

# %%
config = TrainConfig(
    experiment_id=EXP,
    data_root=str(DATA),
    output_dir=str(RUNS / EXP),
    seed=42,
    batch_size=32,
    lr=1e-3,
    max_epochs=50,
    patience=10,
    num_workers=16,
)

start = time.time()
result = train_experiment(config)
print(f"\nwall clock: {(time.time() - start) / 60:.1f} min")
# Out:
# Epoch 1/50 | train loss 0.9278 acc 0.6580 | val loss 0.8958 macro-F1 0.5573
# Epoch 2/50 | train loss 0.7068 acc 0.7428 | val loss 0.9117 macro-F1 0.5188
# Epoch 3/50 | train loss 0.6030 acc 0.7837 | val loss 0.7408 macro-F1 0.6085
# Epoch 4/50 | train loss 0.5291 acc 0.8049 | val loss 0.6552 macro-F1 0.6552
# Epoch 5/50 | train loss 0.5206 acc 0.8097 | val loss 0.6483 macro-F1 0.6814
# Epoch 6/50 | train loss 0.4915 acc 0.8206 | val loss 0.7596 macro-F1 0.6609
# Epoch 7/50 | train loss 0.4639 acc 0.8231 | val loss 0.6637 macro-F1 0.6480
# Epoch 8/50 | train loss 0.4568 acc 0.8344 | val loss 0.7019 macro-F1 0.7162
# Epoch 9/50 | train loss 0.4085 acc 0.8492 | val loss 0.8891 macro-F1 0.6179
# Epoch 10/50 | train loss 0.4134 acc 0.8460 | val loss 0.6648 macro-F1 0.6437
# Epoch 11/50 | train loss 0.3805 acc 0.8561 | val loss 0.7770 macro-F1 0.6082
# Epoch 12/50 | train loss 0.3683 acc 0.8617 | val loss 0.7621 macro-F1 0.6564
# Epoch 13/50 | train loss 0.3468 acc 0.8717 | val loss 0.7507 macro-F1 0.6534
# Epoch 14/50 | train loss 0.3368 acc 0.8748 | val loss 0.6377 macro-F1 0.7166
# Epoch 15/50 | train loss 0.3434 acc 0.8744 | val loss 0.6763 macro-F1 0.6955
# Epoch 16/50 | train loss 0.3494 acc 0.8684 | val loss 0.8307 macro-F1 0.6081
# Epoch 17/50 | train loss 0.3129 acc 0.8854 | val loss 0.6070 macro-F1 0.7132
# Epoch 18/50 | train loss 0.3112 acc 0.8842 | val loss 0.6199 macro-F1 0.6842
# Epoch 19/50 | train loss 0.3002 acc 0.8893 | val loss 0.8135 macro-F1 0.6859
# Epoch 20/50 | train loss 0.2781 acc 0.8945 | val loss 0.5112 macro-F1 0.7208
# Epoch 21/50 | train loss 0.2890 acc 0.8893 | val loss 0.7335 macro-F1 0.6896
# Epoch 22/50 | train loss 0.2917 acc 0.8920 | val loss 0.6250 macro-F1 0.6940
# Epoch 23/50 | train loss 0.2568 acc 0.9059 | val loss 0.6295 macro-F1 0.6973
# Epoch 24/50 | train loss 0.2609 acc 0.9053 | val loss 0.5603 macro-F1 0.7128
# Epoch 25/50 | train loss 0.2576 acc 0.9041 | val loss 0.5429 macro-F1 0.7144
# Epoch 26/50 | train loss 0.2370 acc 0.9133 | val loss 0.7048 macro-F1 0.7113
# Epoch 27/50 | train loss 0.2659 acc 0.8992 | val loss 0.5703 macro-F1 0.7069
# Epoch 28/50 | train loss 0.2323 acc 0.9141 | val loss 0.7080 macro-F1 0.7206
# Epoch 29/50 | train loss 0.2454 acc 0.9069 | val loss 0.6405 macro-F1 0.7037
# Epoch 30/50 | train loss 0.2424 acc 0.9120 | val loss 0.6765 macro-F1 0.7242
# Early stopping at epoch 30 (patience 10)
#
# === E5 test metrics (best checkpoint) ===
# Accuracy          0.7949
# Balanced accuracy 0.7118
# Macro F1          0.6814
# Per-class F1      {"akiec": 0.6047, "bcc": 0.6186, "bkl": 0.6344, "df": 0.5385, "mel": 0.5062, "nv": 0.9, "vasc": 0.9677}
#
# wall clock: 10.7 min

# %% [markdown]
# ## Results

# %%
import pandas as pd
from ham10000.constants import CLASS_NAMES

m = result["test_metrics"]
report = m["classification_report"]

print(f"accuracy          {m['accuracy']:.4f}")
print(f"balanced accuracy {m['balanced_accuracy']:.4f}")
print(f"macro F1          {m['macro_f1']:.4f}")
print(f"macro AUC (OvR)   {m['macro_auc_ovr']:.4f}\n")

table = pd.DataFrame([{
    "class": c,
    "precision": report[str(i)]["precision"],
    "recall": report[str(i)]["recall"],
    "f1": report[str(i)]["f1-score"],
    "support": int(report[str(i)]["support"]),
} for i, c in enumerate(CLASS_NAMES)]).set_index("class").round(4)
print(table)

rq2 = (report[str(CLASS_NAMES.index("mel"))]["recall"]
       + report[str(CLASS_NAMES.index("bcc"))]["recall"]) / 2
print(f"\nRQ2 criterion, mean(recall MEL, recall BCC) = {rq2:.4f}")
# Out:
# accuracy          0.7949
# balanced accuracy 0.7118
# macro F1          0.6814
# macro AUC (OvR)   0.9537
#
#        precision  recall      f1  support
# class
# akiec     0.4906  0.7879  0.6047       33
# bcc       0.6818  0.5660  0.6186       53
# bkl       0.5902  0.6857  0.6344      105
# df        0.5385  0.5385  0.5385       13
# mel       0.4841  0.5304  0.5062      115
# nv        0.9277  0.8739  0.9000      690
# vasc      0.9375  1.0000  0.9677       15
#
# RQ2 criterion, mean(recall MEL, recall BCC) = 0.5482

# %% [markdown]
# ### Training curve
#
# Val loss is what early stopping watches. Val macro F1 is what actually matters, and the
# two do not always move together.

# %%
import matplotlib.pyplot as plt

h = pd.read_csv(RUNS / EXP / "history.csv")
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(h.epoch, h.train_loss, label="train")
axes[0].plot(h.epoch, h.val_loss, label="val")
best = h.loc[h.val_loss.idxmin()]
axes[0].axvline(best.epoch, ls="--", c="grey", lw=1)
axes[0].annotate(f"best epoch {int(best.epoch)}", (best.epoch, best.val_loss),
                 textcoords="offset points", xytext=(8, 10), fontsize=8)
axes[0].set_xlabel("epoch"); axes[0].set_ylabel("loss"); axes[0].legend()
axes[0].set_title(f"{EXP} loss")

axes[1].plot(h.epoch, h.val_macro_f1, color="#D54407", label="val macro F1")
axes[1].plot(h.epoch, h.val_balanced_accuracy, color="#2E7D32", label="val balanced acc")
axes[1].set_xlabel("epoch"); axes[1].legend(); axes[1].set_title(f"{EXP} validation metrics")
plt.show()

print(f"stopped after {len(h)} epochs, best val loss {h.val_loss.min():.4f} at epoch {int(best.epoch)}")
# Out:
# stopped after 30 epochs, best val loss 0.5112 at epoch 20

# %% [markdown]
# ### Confusion matrix

# %%
import numpy as np

cm = np.array(m["confusion_matrix"], dtype=float)
norm = cm / np.maximum(cm.sum(axis=1, keepdims=True), 1)

fig, ax = plt.subplots(figsize=(6, 5))
ax.imshow(norm, cmap="Oranges", vmin=0, vmax=1)
for i in range(7):
    for j in range(7):
        if cm[i, j]:
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", fontsize=8,
                    color="white" if norm[i, j] > 0.55 else "black")
ax.set_xticks(range(7), [c.upper() for c in CLASS_NAMES], rotation=45)
ax.set_yticks(range(7), [c.upper() for c in CLASS_NAMES])
ax.set_xlabel("predicted"); ax.set_ylabel("true")
ax.set_title(f"{EXP} confusion matrix (counts, shaded by row-normalised recall)")
ax.grid(False)
plt.show()

mel, nv = CLASS_NAMES.index("mel"), CLASS_NAMES.index("nv")
print(f"melanomas called NV: {int(cm[mel, nv])} of {int(cm[mel].sum())}")
print("This is the clinically costly error: a cancer sent home as a benign mole.")
# Out:
# melanomas called NV: 33 of 115
# This is the clinically costly error: a cancer sent home as a benign mole.

# %% [markdown]
# ### Files written
#
# These five are what the analysis notebooks read. Nothing later re-derives them.

# %%
for f in sorted((RUNS / EXP).iterdir()):
    print(f"{f.name:<24} {f.stat().st_size/1e6:>8.2f} MB")
# Out:
# checkpoint_best.pt          27.18 MB
# checkpoint_last.pt          27.18 MB
# config.json                  0.00 MB
# history.csv                  0.00 MB
# test_metrics.json            0.00 MB
# test_predictions.csv         0.02 MB
