# %% [markdown]
# # E1 - MobileNetV2, augmentation only, 224px
#
# | | |
# |---|---|
# | Architecture | `mobilenet_v2` |
# | Imbalance strategy | `augmentation` |
# | Input resolution | 224x224 |
# | Group | confirmatory 2x3 factorial |
# | Optimiser | Adam, lr 1e-3, betas (0.9, 0.999) |
# | Batch size | 32 |
# | Schedule | max 50 epochs, early stopping on val loss, patience 10 |
# | Seed | 42 |
#
# This is the control. No re-weighting, no resampling, just the shared
# augmentation pipeline and plain cross-entropy. Every other number in the study gets
# read against this one.
#
# It is also the first run, so it creates `runs/splits/seed42_lesion_stratified.json`.
# The remaining eleven notebooks load that file instead of re-deriving the split, which
# is what keeps all twelve on byte-identical partitions. Check the split hash printed
# below matches in every later notebook.
#
# Training is checkpointed after every epoch. If the pod drops, re-run the training cell
# and it picks up from the last completed epoch rather than starting over.

# %%
import json, sys, time
from pathlib import Path

# Works whether the kernel starts in notebooks/ or at the repo root.
ROOT = Path.cwd()
while not (ROOT / "src" / "ham10000").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

# /workspace is a MooseFS network volume and per-file reads over FUSE were the
# bottleneck, not the GPU: 45 img/s there against 241 img/s from RAM. Notebook 01
# stages a copy into /dev/shm. Fall back to the on-disk copy if it is missing,
# since tmpfs does not survive a pod restart.
FAST = Path("/dev/shm/ham_data")
DATA = FAST if (FAST / "HAM10000_metadata.csv").exists() else ROOT / "data"
RUNS = ROOT / "runs"
print("repo:   ", ROOT)
print("data:   ", DATA, "(RAM)" if str(DATA).startswith("/dev/shm") else "(disk, slower)")
# Out:
# repo:    /workspace/ham10000-cnn-comparison
# data:    /dev/shm/ham_data (RAM)

# %%
from ham10000.constants import EXPERIMENTS, experiment_label
from ham10000.train import TrainConfig, train_experiment

EXP = "E1"
print(experiment_label(EXP))
print(EXPERIMENTS[EXP])
# Out:
# E1 MobileNetV2 @224 / Augmentation only
# {'architecture': 'mobilenet_v2', 'strategy': 'augmentation', 'image_size': 224}

# %% [markdown]
# ## Preflight
#
# Confirms the GPU, the data and the shared split before anything expensive starts.

# %%
import torch
from ham10000.split import load_or_create_split, split_hash

assert torch.cuda.is_available(), "No GPU. Stop here."
print("gpu :", torch.cuda.get_device_name(0))

assert (DATA / "HAM10000_metadata.csv").exists(), "Run notebook 01 first."
df, lesion_splits = load_or_create_split(DATA / "HAM10000_metadata.csv",
                                         RUNS / "splits" / "seed42_lesion_stratified.json")
print("split hash :", split_hash(lesion_splits))
print(df.split.value_counts().to_dict())
# Out:
# gpu : NVIDIA RTX A4500
# split hash : f35ac1de18678182
# {'train': 8012, 'test': 1024, 'val': 979}

# %% [markdown]
# ## Train
#
# Expect this to take a while. Roughly 30 to 60 minutes on an A40, depending on how early the run stops.
#
# The cell is safe to re-run: if `test_metrics.json` already exists it returns the cached
# result instead of retraining. Pass `force_rerun=True` if you genuinely want it redone.

# %%
config = TrainConfig(
    experiment_id=EXP,
    data_root=str(DATA),
    output_dir=str(RUNS / EXP),
    seed=42,
    batch_size=32,
    lr=1e-3,
    max_epochs=50,
    patience=10,
    num_workers=16,
)

start = time.time()
result = train_experiment(config)
print(f"\nwall clock: {(time.time() - start) / 60:.1f} min")
# Out:
# Epoch 1/50 | train loss 0.8191 acc 0.7143 | val loss 0.7559 macro-F1 0.3611
# Epoch 2/50 | train loss 0.6865 acc 0.7498 | val loss 0.6841 macro-F1 0.3356
# Epoch 3/50 | train loss 0.6289 acc 0.7698 | val loss 0.6458 macro-F1 0.5340
# Epoch 4/50 | train loss 0.5962 acc 0.7853 | val loss 0.6761 macro-F1 0.4687
# Epoch 5/50 | train loss 0.5799 acc 0.7908 | val loss 0.7426 macro-F1 0.5116
# Epoch 6/50 | train loss 0.5440 acc 0.7966 | val loss 0.7276 macro-F1 0.5405
# Epoch 7/50 | train loss 0.5340 acc 0.8047 | val loss 0.6096 macro-F1 0.6123
# Epoch 8/50 | train loss 0.5138 acc 0.8108 | val loss 0.5287 macro-F1 0.6086
# Epoch 9/50 | train loss 0.4947 acc 0.8215 | val loss 0.6763 macro-F1 0.5317
# Epoch 10/50 | train loss 0.4799 acc 0.8255 | val loss 0.5463 macro-F1 0.6430
# Epoch 11/50 | train loss 0.4735 acc 0.8284 | val loss 0.5867 macro-F1 0.5409
# Epoch 12/50 | train loss 0.4583 acc 0.8279 | val loss 0.4849 macro-F1 0.6588
# Epoch 13/50 | train loss 0.4439 acc 0.8394 | val loss 0.5465 macro-F1 0.6366
# Epoch 14/50 | train loss 0.4339 acc 0.8414 | val loss 0.6188 macro-F1 0.6061
# Epoch 15/50 | train loss 0.4242 acc 0.8459 | val loss 0.5347 macro-F1 0.5952
# Epoch 16/50 | train loss 0.4187 acc 0.8482 | val loss 0.4802 macro-F1 0.6737
# Epoch 17/50 | train loss 0.4005 acc 0.8513 | val loss 0.5683 macro-F1 0.6201
# Epoch 18/50 | train loss 0.4088 acc 0.8505 | val loss 0.5399 macro-F1 0.6016
# Epoch 19/50 | train loss 0.4005 acc 0.8492 | val loss 0.5475 macro-F1 0.6688
# Epoch 20/50 | train loss 0.3771 acc 0.8606 | val loss 0.5278 macro-F1 0.6979
# Epoch 21/50 | train loss 0.3790 acc 0.8658 | val loss 0.5116 macro-F1 0.6799
# Epoch 22/50 | train loss 0.3623 acc 0.8694 | val loss 0.5324 macro-F1 0.6532
# Epoch 23/50 | train loss 0.3686 acc 0.8657 | val loss 0.5014 macro-F1 0.7021
# Epoch 24/50 | train loss 0.3546 acc 0.8651 | val loss 0.4818 macro-F1 0.7039
# Epoch 25/50 | train loss 0.3505 acc 0.8684 | val loss 0.4595 macro-F1 0.7207
# Epoch 26/50 | train loss 0.3323 acc 0.8781 | val loss 0.5331 macro-F1 0.6679
# Epoch 27/50 | train loss 0.3334 acc 0.8754 | val loss 0.5287 macro-F1 0.6530
# Epoch 28/50 | train loss 0.3303 acc 0.8776 | val loss 0.4510 macro-F1 0.7444
# Epoch 29/50 | train loss 0.3152 acc 0.8855 | val loss 0.5570 macro-F1 0.6590
# Epoch 30/50 | train loss 0.3118 acc 0.8827 | val loss 0.6232 macro-F1 0.6375
# Epoch 31/50 | train loss 0.3156 acc 0.8803 | val loss 0.4541 macro-F1 0.7125
# Epoch 32/50 | train loss 0.3067 acc 0.8858 | val loss 0.4723 macro-F1 0.6722
# Epoch 33/50 | train loss 0.2973 acc 0.8907 | val loss 0.4592 macro-F1 0.7380
# Epoch 34/50 | train loss 0.2923 acc 0.8945 | val loss 0.5466 macro-F1 0.7066
# Epoch 35/50 | train loss 0.2917 acc 0.8904 | val loss 0.5440 macro-F1 0.6879
# Epoch 36/50 | train loss 0.2769 acc 0.8940 | val loss 0.5136 macro-F1 0.6972
# Epoch 37/50 | train loss 0.2881 acc 0.8910 | val loss 0.5256 macro-F1 0.6726
# Epoch 38/50 | train loss 0.2720 acc 0.8988 | val loss 0.4825 macro-F1 0.6653
# Early stopping at epoch 38 (patience 10)
#
# === E1 test metrics (best checkpoint) ===
# Accuracy          0.8008
# Balanced accuracy 0.6715
# Macro F1          0.6643
# Per-class F1      {"akiec": 0.6047, "bcc": 0.6972, "bkl": 0.6311, "df": 0.6957, "mel": 0.4732, "nv": 0.9052, "vasc": 0.6429}
#
# wall clock: 13.8 min

# %% [markdown]
# ## Results

# %%
import pandas as pd
from ham10000.constants import CLASS_NAMES

m = result["test_metrics"]
report = m["classification_report"]

print(f"accuracy          {m['accuracy']:.4f}")
print(f"balanced accuracy {m['balanced_accuracy']:.4f}")
print(f"macro F1          {m['macro_f1']:.4f}")
print(f"macro AUC (OvR)   {m['macro_auc_ovr']:.4f}\n")

table = pd.DataFrame([{
    "class": c,
    "precision": report[str(i)]["precision"],
    "recall": report[str(i)]["recall"],
    "f1": report[str(i)]["f1-score"],
    "support": int(report[str(i)]["support"]),
} for i, c in enumerate(CLASS_NAMES)]).set_index("class").round(4)
print(table)

rq2 = (report[str(CLASS_NAMES.index("mel"))]["recall"]
       + report[str(CLASS_NAMES.index("bcc"))]["recall"]) / 2
print(f"\nRQ2 criterion, mean(recall MEL, recall BCC) = {rq2:.4f}")
# Out:
# accuracy          0.8008
# balanced accuracy 0.6715
# macro F1          0.6643
# macro AUC (OvR)   0.9575
#
#        precision  recall      f1  support
# class
# akiec     0.4906  0.7879  0.6047       33
# bcc       0.6786  0.7170  0.6972       53
# bkl       0.6436  0.6190  0.6311      105
# df        0.8000  0.6154  0.6957       13
# mel       0.4862  0.4609  0.4732      115
# nv        0.9106  0.9000  0.9052      690
# vasc      0.6923  0.6000  0.6429       15
#
# RQ2 criterion, mean(recall MEL, recall BCC) = 0.5889

# %% [markdown]
# ### Training curve
#
# Val loss is what early stopping watches. Val macro F1 is what actually matters, and the
# two do not always move together.

# %%
import matplotlib.pyplot as plt

h = pd.read_csv(RUNS / EXP / "history.csv")
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(h.epoch, h.train_loss, label="train")
axes[0].plot(h.epoch, h.val_loss, label="val")
best = h.loc[h.val_loss.idxmin()]
axes[0].axvline(best.epoch, ls="--", c="grey", lw=1)
axes[0].annotate(f"best epoch {int(best.epoch)}", (best.epoch, best.val_loss),
                 textcoords="offset points", xytext=(8, 10), fontsize=8)
axes[0].set_xlabel("epoch"); axes[0].set_ylabel("loss"); axes[0].legend()
axes[0].set_title(f"{EXP} loss")

axes[1].plot(h.epoch, h.val_macro_f1, color="#D54407", label="val macro F1")
axes[1].plot(h.epoch, h.val_balanced_accuracy, color="#2E7D32", label="val balanced acc")
axes[1].set_xlabel("epoch"); axes[1].legend(); axes[1].set_title(f"{EXP} validation metrics")
plt.show()

print(f"stopped after {len(h)} epochs, best val loss {h.val_loss.min():.4f} at epoch {int(best.epoch)}")
# Out:
# stopped after 38 epochs, best val loss 0.4510 at epoch 28

# %% [markdown]
# ### Confusion matrix

# %%
import numpy as np

cm = np.array(m["confusion_matrix"], dtype=float)
norm = cm / np.maximum(cm.sum(axis=1, keepdims=True), 1)

fig, ax = plt.subplots(figsize=(6, 5))
ax.imshow(norm, cmap="Oranges", vmin=0, vmax=1)
for i in range(7):
    for j in range(7):
        if cm[i, j]:
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", fontsize=8,
                    color="white" if norm[i, j] > 0.55 else "black")
ax.set_xticks(range(7), [c.upper() for c in CLASS_NAMES], rotation=45)
ax.set_yticks(range(7), [c.upper() for c in CLASS_NAMES])
ax.set_xlabel("predicted"); ax.set_ylabel("true")
ax.set_title(f"{EXP} confusion matrix (counts, shaded by row-normalised recall)")
ax.grid(False)
plt.show()

mel, nv = CLASS_NAMES.index("mel"), CLASS_NAMES.index("nv")
print(f"melanomas called NV: {int(cm[mel, nv])} of {int(cm[mel].sum())}")
print("This is the clinically costly error: a cancer sent home as a benign mole.")
# Out:
# melanomas called NV: 32 of 115
# This is the clinically costly error: a cancer sent home as a benign mole.

# %% [markdown]
# ### Files written
#
# These five are what the analysis notebooks read. Nothing later re-derives them.

# %%
for f in sorted((RUNS / EXP).iterdir()):
    print(f"{f.name:<24} {f.stat().st_size/1e6:>8.2f} MB")
# Out:
# checkpoint_best.pt          27.18 MB
# checkpoint_last.pt          27.18 MB
# config.json                  0.00 MB
# history.csv                  0.00 MB
# test_metrics.json            0.00 MB
# test_predictions.csv         0.02 MB
